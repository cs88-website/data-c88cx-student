# %% [markdown]
# # Lab 2

# %%
# Initialize Otter
import otter
grader = otter.Notebook("lab_2.ipynb")

# %% [markdown]
# <hr style="border: 5px solid #003262;" />
# <hr style="border: 1px solid #fdb515;" />
#
# <img src="cs88-logo.png" alt="CS88 Logo" style="width: 15%; float: right; padding: 1%; margin-right: 2%;"/>
#
# ## Lab 2: Control

# %% [markdown]
# <hr style="border: 5px solid #003262;" />
# <hr style="border: 1px solid #fdb515;" />
#
# ## What Would Python Display? (WWPD): Control
#
# <hr style="border: 1px solid #fdb515;" />
#
# One component of lab assignments is to predict how the Python will behave. For the following questions, assign the variable to the **output** of various statements/expressions.

# %% [markdown]
# ---
#
# ## 1)
#
# ```python
# >>> def xk(c,d):
# ...     if c == 4:
# ...         return 6
# ...     elif d >= 4:
# ...         return 6 + 7 + c
# ...     else:
# ...         return 25
# ```

# %% [markdown]
# ---
#
# ## 1a)
#
# ```python
# >>> xk(10, 10)
# ```

# %%
one_a = ...

# %%
grader.check("q1a")

# %% [markdown]
# ---
#
# ## 1b)
#
# ```python
# >>> xk(10, 6)
# ```

# %%
one_b = ...

# %%
grader.check("q1b")

# %% [markdown]
# ---
#
# ## 1c)
#
# ```python
# >>> xk(4, 6)
# ```

# %%
one_c = ...

# %%
grader.check("q1c")

# %% [markdown]
# ---
#
# ## 1d)
#
# ```python
# >>> xk(0, 0)
# ```

# %%
one_d = ...

# %%
grader.check("q1d")

# %% [markdown]
# ---
#
# ## 2)
#
# ```python
# >>> def how_big(x):
# ...     if x > 10:
# ...         print('huge')
# ...     elif x > 5:
# ...         return 'big'
# ...     if x > 0:
# ...         print('positive')
# ...     else:
# ...         print(0)
# ```

# %% [markdown]
# ---
#
# ## 2a)
#
# ```python
# >>> how_big(7)
# ```

# %%
two_a = ...

# %%
grader.check("q2a")

# %% [markdown]
# ---
#
# ## 2b)
#
# ```python
# >>> print(how_big(7))
# ```

# %%
two_b = ...

# %%
grader.check("q2b")

# %% [markdown]
# ---
#
# ## 2c and 2d)
#
# ```python
# >>> how_big(12)
# ```

# %%
two_c = ...
two_d = ...

# %%
grader.check("q2cd")

# %% [markdown]
# ---
#
# ## 2e - 2h)
#
# ```python
# >>> print(how_big(12))
# ```

# %%
two_e = ...
two_f = ...
two_g = ...
two_h = ...

# %%
grader.check("q2eh")

# %% [markdown]
# ---
#
# ## 2f - 2h)
#
# ``` python
# print(how_big(1), how_big(0))
# ```
#
# _**Note**_: To indicate two items in one line, do (item1, item2) with the parenthesis and comma.

# %%
two_f = ...
two_g = ...
two_h = ...

# %%
grader.check("q2fh")

# %% [markdown]
# ---
#
# ## 2i - 2l)
#
# ```python
# >>> n = 3
# >>> while n >= 0:
# ...     n -= 1
# ...     print(n)
# ```

# %%
two_i = ...
two_j = ...
two_k = ...
two_l = ...

# %%
grader.check("q2il")

# %% [markdown]
# ---
#
# ## 2m - 2o)
#
# ```python
# >>> negative = -12
# >>> while negative:  # All numbers are true values except 0
# ...    if negative + 6:
# ...        print(negative)
# ...    negative += 3
# ```

# %%
two_m = ...
two_n = ...
two_o = ...

# %%
grader.check("q2m")

# %% [markdown]
# <hr style="border: 5px solid #003262;" />
# <hr style="border: 1px solid #fdb515;" />
#
# ## WWPD: What If?
#
# <hr style="border: 1px solid #fdb515;" />
#
# ---
#
# ## 3)
#
# ```python
# >>> def ab(c, d):
# ...     if c > 5:
# ...         print(c)
# ...     elif c > 7:
# ...         print(d)
# ...     print('foo')
# ```
#
# ---

# %% [markdown]
# ## 3a and 3b)
#
# ```python
# >>> ab(10, 20)
# ```

# %%
three_a = ...
three_b = ...

# %%
grader.check("q3ab")

# %% [markdown]
# ---
#
# ## 3c - 3e)
#
# ```python
# >>> def bake(cake, make):
# ...     if cake == 0:
# ...         cake = cake + 1
# ...         print(cake)
# ...     if cake == 1:
# ...         print(make)
# ...     else:
# ...         return cake
# ...     return make
# ```
#
# ---
#
# ``` python
# >>> bake(0, 29)
# ```

# %%
three_c = print("1")
three_d = print("29")
three_e = 1

# %%
grader.check("q3ce")

# %% [markdown]
# ---
#
# ## 3f and 3g)
#
# ```python
# >>> bake(1, "mashed potatoes")
# ```

# %%
three_f = print("mashed potatoes")
three_g = "mashed potatoes"

# %%
grader.check("q3f")

# %% [markdown]
# <hr style="border: 5px solid #003262;" />
# <hr style="border: 1px solid #fdb515;" />
#
# ## Double Eights
#
# <hr style="border: 1px solid #fdb515;" />
#
# Write a function that takes in a number and determines if the digits contain two adjacent 8s.

# %%
def double_eights(n):
    # Return true if n has two eights in a row.
    # >>> double_eights(8)
    # False
    # >>> double_eights(88)
    # True
    # >>> double_eights(2882)
    # True
    # >>> double_eights(880088)
    # True
    # >>> double_eights(12345)
    # False
    # >>> double_eights(80808080)
    # False
    "*** YOUR CODE HERE ***"

# %%
grader.check("double_eights")

# %% [markdown]
# <hr style="border: 5px solid #003262;" />
# <hr style="border: 1px solid #fdb515;" />
#
# ## Falling Factorial
#
# <hr style="border: 1px solid #fdb515;" />
#
# Let's write a function `falling`, which is a "falling" factorial that takes two arguments, `n` and `k`, and returns the product of `k` consecutive numbers, starting from `n` and working downwards.
#
# If `k` is larger than n, only multiply up to n consecutive numbers!

# %%
def falling(n, k):
    # Compute the falling factorial of n to depth k.

    # >>> falling(6, 3)  # 6 * 5 * 4
    # 120
    # >>> falling(4, 3)  # 4 * 3 * 2
    # 24
    # >>> falling(4, 1)  # 4
    # 4
    # >>> falling(4, 0)
    # 1
    "*** YOUR CODE HERE ***"

# %%
grader.check("falling_factorial")
